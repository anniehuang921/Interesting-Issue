# %% [markdown]
# ##登陸實價
# 待會遇到驗證碼，存了它！

# %%
import requests

# %% [markdown]
# ##<b style="color:#FF7777">**我們想要記錄這些動作 **</b>

# %%
s=requests.Session()

# %%
res=s.get("http://lvr.land.moi.gov.tw/N11/homePage.action")#首頁

# %%
img=s.get("http://lvr.land.moi.gov.tw/N11/ImageNumberN13?")#驗證碼

# %%
img.text
# Out:
# u'\ufffd\ufffd\ufffd\ufffd\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\ufffd\ufffd\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\ufffd\ufffd\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\ufffd\ufffd\x00\x11\x08\x00\x1e\x00F\x03\x01"\x00\x02\x11\x01\x03\x11\x01\ufffd\ufffd\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\ufffd\ufffd\x00\ufffd\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\ufffd\ufffd\ufffd\x08#B\ufffd\ufffd\x15R\ufffd\ufffd$3br\ufffd\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\x00\x1f\x01\x00\x03\x01\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\ufffd\ufffd\x00\ufffd\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\ufffd\x08\x14B\ufffd\ufffd\ufffd\ufffd\t#3R\ufffd\x15br\ufffd\n\x16$4\ufffd%\ufffd\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\ufffd\ufffd\x0b\x10\x00$\ufffd\x00\x15B\ufffdY\ufffdu\rSS\ufffdl\ufffd\ufffd\ufffdZY\ufffd.\ufffd\x0c\ufffd;\ufffd\ufffd\x03g\ufffd_,\ufffd\ufffd\t\ufffdr\x08\x18^;\ufffdT>\x1e\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffdu\ufffd\ufffd\ufffd5)7\ufffd\ufffd\ufffd*\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffdA\ufffd\x04\ufffd\ufffd\x02\ufffd\x0f\ufffdWz6\ufffd\ufffd\x17Z\ufffd\ufffd]^1cq\ufffdO\ufffd\ufffd{\ufffdI\ufffd]$03H\x01O)c`7|\ufffd\ufffdvA\ufffd\ufffdKm)\ufffd\ufffd\ufffd\x1d\x0fD\ufffd\x07\ufffd4\ufffd\x0c\ufffdC=\ufffdO$\ufffd3\x08-,\ufffd#\ufffdn.d$\x0c"dg\x19\x199\x1d@\ufffd@54/\x13\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\x0b\x14\x13\ufffd7\ufffd\ufffd\ufffd\ufffd\ufffd\ufffdK\ufffd\ufffd\ufffd\ufffd\ufffd8\'9;pG@BQ\ufffd,\ufffd\x0f\ufffd\ufffd\ufffd\ufffd\ufffdX7I\ufffdF\ufffd\x17\x0b\ufffd\ufffd\x08\ufffd\x01<d\ufffd\x00\x0e\ufffd\ufffd\ufffd\x1e\x19\ufffd;\ufffd\ufffd_\x10\x11o\x19\ufffdm>\x03s\x10I\nH\ufffd\ufffd+\x13\ufffd\ufffd\ufffd\ufffd\x1b\ufffd\ufffd\ufffd\ufffd\x1d\ufffd\\\ufffd\ufffd\ufffd\r%c\ufffd\ufffd\ufffd\ufffdV[\ufffd\ufffd\ufffdY\ufffd\x0b\ufffd\ufffd\ufffdJ\ufffd\ufffd\ufffd\ufffd\x16[\x17\ufffd\ufffd(\ufffdr&\ufffdfH\ufffd\ufffd\ufffd\x0eU\ufffd:\x10T`V\ufffd\ufffd\'\ufffd\ufffd\ufffdz\x1d\ufffd\ufffd\ufffdM<\ufffde\ufffd\ufffd$\ufffdY\ufffd\ufffd(I$\ufffdI<\ufffd\ufffdR\ufffd%\ufffd\x19\ufffd\ufffd\ufffd\ufffd\ufffduk\ufffdO\ufffdF<W\x7f\ufffd:\ufffda\ufffd\x19\ufffd!\ufffd[\n\ufffd\ufffdp\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd_\ufffd\ufffd\ufffd\r[M\ufffd\ufffd\ufffd%Id\ufffdh\ufffdK c\ufffd\ufffd\ufffd-\x16\ufffd\ufffd)g]\ufffd\ufffdw.\x1bp@*\x0f\x1a\ufffd\x17Zw\ufffd\ufffdM5\ufffd\ufffd[T\ufffdM\x1e\ufffd\ufffd\ufffdU\ufffd\ufffd\x0e\x19\ufffd)\x05p\ufffd\ufffd@$0^1\ufffd\ufffd\ufffd\ufffd\ufffdG\ufffd\ufffdO\ufffd\u ...

# %% [markdown]
# ##把驗證碼存起來

# %%
rm login_img.jpg
# Out:
# rm: login_img.jpg: No such file or directory

# %%
f=open("login_img.jpg","w")
for chunk in img.iter_content():
    f.write(chunk)
f.close()

# %% [markdown]
# ![](login_img.jpg)

# %% [markdown]
# 大部份IPython會因為把圖片給暫存了，所以再跑一次時，新的驗證碼出不來。這時候為了開資料夾，以便找檔案可以用!open .

# %%
# !open .

# %%
login_num='4017'

# %% [markdown]
# ##翱翔～登錄頁面！

# %%
text="command=login&rand_code=%s&in_type=land&formaturl="%login_num

# %%
data=dict(map(lambda x:tuple(x.split("=")),text.split("&")))

# %%
data #其實有他們就滿意了'command': 'login','rand_code': '7922'
# Out:
# {'command': 'login', 'formaturl': '', 'in_type': 'land', 'rand_code': '4017'}

# %%
log=s.post("http://lvr.land.moi.gov.tw/N11/login.action",data)

# %%
log
# Out:
# <Response [200]>

# %%
print log.text
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <head>
#
# <meta http-equiv="X-UA-Compatible" content="IE=EmulateIE8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <link rel="shortcut icon" href="/INC/images/n11_favicon.ico" />
# <link rel="stylesheet" type="text/css" href="/INC/css/n11_style.css" />
# <link rel="stylesheet" type="text/css" href="/INC/css/google.css" />
# <link rel="stylesheet" type="text/css" href="/INC/css/style.css" />
# <link href="/INC/css/n11_qr_style.css" rel="stylesheet" type="text/css" />
# <script src="/INC/SpryAssets/SpryTabbedPanels.js" type="text/javascript"></script>
# <link href="/INC/css/SpryTabbedPanels.css" rel="stylesheet" type="text/css" />
# <script type="text/javascript" src="/INC/js/jquery-1.6.4.min.js"></script>
# <script type="text/javascript" src="/INC/js/jquery.simplemodal.js"></script>
# <script type="text/javascript" src="/INC/js/basic.js"></script>
# <script type="text/javascript" src="/INC/openlayers/OpenLayers.js"></script>
# <!--<script src="http://maps.google.com/maps/api/js?v=3&amp;sensor=false&version=20150519"></script>-->
# <script type="text/javascript" src="./js/map_layer.js?version=20150519"></script>
# <!-- <script type="text/javascript" src="./openlayers/lib/OpenLayers/Lang/zh-TW.js"></script> -->
# <script type="text/javascript" src="/INC/js/qt_util.js"></script>
# <script type="text/javascript" src="/INC/js/qt_map.js?version=20150519"></script>
# <script type="text/javascript" src="/INC/js/qt_view.js?version=20150519"></script>
# <script type="text/javascript" src="/INC/js/city_town.js?version=20150519"></script>
# <script type="text/javascript" src="/INC/js/qt_ajax.js?version=20150519"></script>
# <!-- <script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?sensor=false"></script> -->
# <script type="text/javascript" src="/INC/js/jquery-latest.min.js"></script>
# <script type="text/javascript" src="/INC/js/jquery.pagination.js"></script>
# <script type="text/javascript" src="/INC/js/qt_base64.js"></script>
# <link type="text/css" href="/INC/css/jquery-ui-1.8.11.custom.css" rel="Stylesheet" />
# <script type="text/javascript" src="/INC/js/jquery-ui-1.8.11.custom.min.js"></script>
# <link type="text/css" href="/INC/css/tip-yellow.css" rel="Stylesheet" />
# <script type="text/javascript" src="/INC/js/jquery.poshytip.js"></script>
# <script type="text/javascript" src="/INC/js/jquery.blockUI.js"></script>
# <script type='text/javascript' src="/INC/js/jquery.timers.js"></script>
# <script type="text/javascript">
#    if (typeof (JSON) == 'undefined') { //沒有 JSON 時才讓 browser 下載 json2.js
#       $('head').append($("<script type='text/javascript' src='/INC/js/json2.js'>"));
#    }
# </script>
#
# <title>不動產交易實價查詢服務網</title>
# </head>
#
#
# <body onLoad="initViewSize();mapinit('map_openlayers','osm' );" >
# <script>
# //$("body").everyTime('5s','myTimer2',timerFunc,1);
# function timerFunc(){
# 		if(!$('#sysinfodialog').dialog( "isOpen" )){
# 				$('#sysinfodialog').dialog('open');
# 		}
# }
# </script>
# <div class="container">
#
#   <div class="header"><!-- start .header -->
#     <table width="100%" border="0" cellspacing="0" cellpadding="0">
#       <tr>
#         <td class="logo"></td>
#         <td class="main_pic"></td>
#       </tr>
#       <tr>
#         <td colspan="3"><table width="100%" border="0" cellpadding="0" cellspacing="0">
#
#           <tr>
#             <td rowspan="2"  valign="top" class="header_left_bg"><a tabindex=1 accesskey="U"  href="./sitemap/sitemap.htm"  target="_blank" title="上方選單區域 交易類別" style="text-decoration: none; color:#fff"><font color="#fff">:::</font></a></td>
#             <td class="menu_bar"><div id="menubar_1">
#               <div id="menubar_2">
#                 <div id="menubar_3">
#
#
#                   <div id="menubar_4"><a href="#" tabindex=2 ><img border="0" onmouseout="MM_swapImgRestore()" height="32" onkeypress="document.location='login.action?command=logout'" alt="首頁" name="home" width="131" onclick="document.location='login.action?command=logout'" src="/INC/images/home.png" onmouseover="MM_swapImage('home','','/INC/images/home_on.png',1)" onkeypress="document.location='login.action?command=logout'" onfocus="MM_swapImage('home','','/INC/images/home_on.png',1)" onblur="MM_swapImgRestore()"></a></div>
#                   <a href="#" tabindex=3 ><img src="/INC/images/l_h_s_on.png" alt="土地建物買賣" name="land-house-sale" width="163" height="32" border="0" ></a> </div>
#                 <a href="#" tabindex=4><img border="0" onmouseout="MM_swapImgRestore()" height="32" name="per-house-sale" onkeypress="chang_menu('pre_sale');" alt="預售屋買賣" width="140" onclick="chang_menu('pre_sale');" src="/INC/images/p_h_s.png" onmouseover="MM_swapImage('per-house-sale','','/INC/images/p_h_s_on.png',1)" onkeypress="chang_menu('pre_sale');" onfocus="MM_swapImage('per-house-sale','','/INC/images/p_h_s_on.png',1)" onblur="MM_swapImgRestore()"></a> </div>
#             <a href="#" tabindex=5 ><img src="/INC/images/l_h_r.png" alt="土地建物租賃" name="land-house_rent" width="154" height="32" border="0" onclick="chang_menu('rent');" onMouseOver="MM_swapImage('land-house_rent','','/INC/images/l_h_r_on.png',1)" onMouseOut="MM_swapImgRestore()" onkeypress="chang_menu('rent');"></a> </div></td>
#
#
#             <td class="main_pic_2"></td>
#             <td rowspan="2" class="header_right_bg"></td>
#           </tr>
#
#
#  <!--menu-->
#
#
# 		<script type="text/javascript">
# //		  catchCodeItem('PAYTYPE','check','AA02_Chk');
# 		  catchCodeItem('BUILDTYPE','select','Qry_build');
# 		  getCountry("Qry_city");
# 		</script>
#
#  <form id ='searchpos'>
# 		 <tr >
#             <td colspan="2" class="header_search_bg"><table width="100%" border="0" cellspacing="0" cellpadding="0" summary="排版表格">
#               <tr>
# 							<td  width="0" ><a accesskey="Q"  href="./sitemap/sitemap.htm"  target="_blank" title="上方查詢區域 輸入條件" style="text-decoration: none; color:#fff"></a></td>
# 							<td  colspan="4">
# 							 <table width="100%" border="0" cellspacing="0" cellpadding="0" summary="排版表格">
# 							  <tr>
# 								<td>
# 							  <img src="/INC/images/counties_region.png" width="70" height="25"   alt="縣市區域" title ="縣市區域">
# 							  <span class="search_text"><font color=red>＊</font></span><select  name="Qry_city" class="search_box" id="Qry_city"  title ="縣市" onChange="changeArea('Qry_city','Qry_area_office');changeToolImg('normal_tools_img_hand');toggleControl('none');$('#frame').attr('checked', false);pos_city('Qry_city');">
# 								<option >縣市</option>
# 								</select>
# 							  <select  title ="鄉鎮市區"  name="Qry_area_office" class="search_box" id="Qry_area_office" onChange="changeToolImg('normal_tools_img_hand');toggleControl('none');$('#frame').attr('checked', false);pos_area('Qry_city','Qry_area_office');" >
# 								<option value="">鄉鎮市區</option>
# 							  </select>
# 							  <input name="Chkb_Qry_paytype" type="checkbox" class="search_td_up" id="Chkb_Qry_paytype" onClick="chk_paytype()" checked value="1">
# 							  <img src="/INC/images/h_l_pic.png" alt="土地加建物" name="house_land" width="107" height="15" class="search_td_up" id="house_land">
# 							  <input name="Chkb_Qry_paytype" type="checkbox" class="search_td_up" id="Chkb_Qry_paytype" onClick="chk_paytype()"  value="2">
# 							  <img src="/INC/images/l_h_p_pic.png" alt="土地加建物加車位" name="house_land_parking_space" width="146" height="15" class="search_td_up" id="house_land_parking_space">
# 							  <input name="Chkb_Qry_paytype" type="checkbox" class="search_td_up" id="Chkb_Qry_paytype" onClick="chk_paytype()"   value="3">
# 							  <img src="/INC/images/l_pic.png" alt="土地" name="land" width="30" height="15" class="search_td_up" id="land">
# 							  <input name="Chkb_Qry_paytype" type="checkbox" class="search_td_up" id="Chkb_Qry_paytype" onClick="chk_paytype()"   value="4">
# 							  <img src="/INC/images/b_pic.png" alt="建物" name="land" width="30" height="15" class="search_td_up" id="land">
# 							  <input name="Chkb_Qry_paytype" type="checkbox" class="search_td_up" id="Chkb_Qry_paytype" onClick="chk_paytype()" value="5">
# 							  <img src="/INC/images/p_pic.png" alt="車位" name="parking_space" width="29" height="15" class="search_td_up" id="parking_space">
# 								<input type="hidden" name="Qry_paytype" id="Qry_paytype" value="">
# 								<input type="hidden" name="btm_left_lon" id="btm_left_lon" value="">
# 								<input type="hidden" name="top_right_lon" id="top_right_lon" value="">
# 								<input type="hidden" name="btm_left_lat" id="btm_left_lat" value="">
# 								<input type="hidden" name="top_right_lat" id="top_right_lat" value="">
# 								<input type="hidden" name="radius" id="radius" value="">
# 								<input type="hidden" name="type" id="type" value="">
# 								<input type="hidden" name="Qry_order" id="Qry_order" value="QA08&desc">
# 								<input type="hidden" name="Printlist" id="Printlist" value="">
# 								<input type="hidden" name="Qry_doorno" id="Qry_doorno" value="">
# 								<input type="hidden" name="Qry_unit" id="Qry_unit" value="">
# 								<input type="hidden" name="avg_price" id="avg_price" value="">
# 								<input type="hidden" name="intype" id="intype" value="land">
# 						 </td>
# 							<div id="tokenDiv">
# 							</div>
# 							<td valign="top" colspan="2"><img src="/INC/images/year.png" alt="屋齡"  title ="屋齡區間">
# 								<input name="Qry_buildyear_s" type="text" class="search_box" id="Qry_buildyear_s" size="1" maxlength="2">
# 								<span class="search_text">~</span>
# 								<input name="Qry_buildyear_e" type="text" class="search_box" id="Qry_buildyear_e" size="1" maxlength="2">
# 								</td>
# 							  </tr>
# 							 </table>
# 							</td>
# 						</tr>
#
# 						<tr>
# 						<td></td>
# 						<td  width="374"  >
# 							<span id ='build'>
# 							<img src="/INC/images/building_type.png" width="70" height="25" alt="建物類型" title ="建物類型">
# 							<span class="search_text">　</span><select name="Qry_build" class="search_box" id="Qry_build">
# 							<option value="">請選擇</option>
# 							</select></span>
# 						</td>
# 						<td width="312" >
#
# 						<img src="/INC/images/sum.png" width="70" height="25" alt="交易總價" title ="交易總價區間">
#
#
# 							<input name="Qry_price_s" type="text" class="search_box" id="Qry_price_s" size="6" maxlength="8">
# 							<span class="search_text">~</span>
# 							<input name="Qry_price_e" type="text" class="search_box" id="Qry_price_e" size="6" maxlength="8">
# 							<span class="search_text">萬元</span>
# 					</td>
# 					<td  width="190" valign="middle" rowspan = '3' >
# 						<table width="100%" border="0" cellspacing="0" cellpadding="0" summary="排版表格">
# 							<tr>
# 								<td valign="center" >
# 								<input title="使用分區" id="land_chk" name="land_chk" onclick="checked_land('land_chk','Qry_land','Qry_landclass');" type="checkbox">
# 								</td>
# 								<td>
# 									<span class="search_text1" >
# 										<img src="/INC/images/use_zoning.png" alt="使用分區" >
# 									</span>
# 								</td>
# 								<td>
# 									<select id="Qry_land" class="search_box"  onChange="changeLand('Qry_land','Qry_landclass');" disabled  >
# 										<option value=''>-----------------</option>
# 									</select>
# 								</td>
# 							</tr>
# 							<tr>
# 								<td>&nbsp;
# 								</td>
# 								<td>&nbsp;
# 								</td>
# 								<td>
# 									<select id="Qry_landclass" class="search_box"  disabled >
# 											<option value=''>-----------------</option>
# 									</select>
# 								</td>
# 							</tr>
# 							<tr>
# 								<td>&nbsp;
# 								</td>
# 								<td colspan ='2'><img src="/INC/images/build_pattern.png" title ="建物格局" alt="建物格局">
# 									<input name="Qry_pattern" type="text" class="search_box" id="Qry_pattern"  title ="3房2廳2衛有隔間，輸入方式：3/2/2/Y<br>3房2廳2衛無隔間，輸入方式：3/2/2/N" size="8" maxlength="30">
# 								</td>
# 							</tr>
# 						</table>
#
# 					</td>
# 					</td>
# 					<td align="center"rowspan = '3' >
# 						<table width="100%" border="0" cellspacing="0" cellpadding="0" summary="排版表格">
# 							<tr  height="40" >
# 								<td valign="center"  >
# 									<a onmouseout="MM_swapImgRestore()" href="#" onmouseover="MM_swapImage('search_1','','/INC/images/search_br_on.png',1)" onfocus="MM_swapImage('search_1','','/INC/images/search_br_on.png',1)" onblur="MM_swapImgRestore()"><img src="/INC/images/search_br.png" alt="搜尋" name="search_1" id="search_1"   border="0" title ="搜尋" width="60" height="31" ></a>
# 								</td>
# 							</tr>
# 							<tr  height="40" >
# 								<td>
# 								 <span id='search_average'  >
# 										<a onmouseout="MM_swapImgRestore()" href="#" onmouseover="MM_swapImage('search_2','','/INC/images/average_price_on.png',1)"
# 										onfocus="MM_swapImage('search_2','','/INC/images/average_price_on.png',1)" onblur="MM_swapImgRestore()">
# 										<img alt="搜尋範圍均價計算" title="搜尋範圍均價計算" id="search_2" name="search_2"
# 										onclick="checkBox2hidden_value();$('#avg_price').val('on');Run_submit();$('#dialog').jqmHide();" src="/INC/images/average_price_br.png" onkeypress="checkBox2hidden_value();$('#avg_price').val('on');Run_submit();$('#dialog').jqmHide();" width="60" height="31"></a></span>
# 										<span id='search_average_not' style="display:none"  >
# 									 <img src="/INC/images/average_price_not.png"  name="no_search_2" alt=" " width="60" height="31"  id="no_search_2" ></span>
# 								</td>
# 							</tr>
# 						</table>
# 					</td>
# 				</tr>
# 			  <tr>
# 				<td></td>
# 				<td><img src="/INC/images/transaction_period.png" width="70" height="25" alt="交易期間" title ="交易期間">
# 				  <span class="search_text">　</span><input name="Qry_p_yyy_s" type="text" class="search_box" id="Qry_p_yyy_s" size="3" maxlength="3"  value="103">
# 				  <span class="search_text">年 </span>
# 					<select id="Qry_season_s" class="search_box"   >
# 					 <option value=''>----</option><option value=1 >1</option><option value=2 >2</option><option value=3 selected >3</option><option value=4 >4</option><option value=5 >5</option><option value=6 >6</option><option value=7 >7</option><option value=8 >8</option><option value=9 >9</option><option value=10 >10</option><option value=11 >11</option><option value=12 >12</option>
# 					</select>
# 				  </select>
# 				  <span class="search_text">月~</span>
# 				  <input name="Qry_p_yyy_e" type="text" class="search_box" id="Qry_p_yyy_e" size="3" maxlength="3" value="104">
# 				  <span class="search_text">年</span>
# 					<select id="Qry_season_e" class="search_box"   >
# 					 <option value=''>----</option><option value=1 >1</option><option value=2 >2</option><option value=3 selected >3</option><option value=4 >4</option><option value=5 >5</option><option value=6 >6</option><option value=7 >7</option><option value=8 >8</option><option value=9 >9</option><option value=10 >10</option><option value=11 >11</option><option value=12 >12</option>
# 					</select>
# 				  <span class="search_text">月</span></td>
#
#
# 				<td>
#
# 				<img src="/INC/images/unit_price.png" width="70" height="25" alt="交易單價"  title ="交易單價區間">
#
#
# 				  <input name="Qry_unit_price_s" type="text" class="search_box" id="Qry_unit_price_s" size="6" maxlength="8" >
# 				  <span class="search_text">~</span>
# 				  <input name="Qry_unit_price_e" type="text" class="search_box" id="Qry_unit_price_e" size="6" maxlength="8">
# 					<span class="search_text">萬元</span>
#
# 				</td>
# 			</tr>
# 			<tr>
# 				<td></td>
# 				<td>
# 				<span id ='road'  >
# 				<img  id ='road_img'  src="/INC/images/section_number.png" width="70" height="25"  title ="區段化門牌"  alt="區段化門牌">
# 				<span class="search_text">&nbsp;&nbsp;</span>
# 				<input name="Qry_road" type="text" class="search_box" id="Qry_road" size="20" maxlength="30"  title ="可輸入任意字數" >
# 				<span class="search_text">(可輸入任意字數)</span>
# 				</span>
# 				</td>
# 				<td   valign="top"><img src="/INC/images/total_area.png" width="70" height="25" title ="移轉總面積" alt="移轉總面積區間">
# 					<input  name="Qry_area_s" type="text" class="search_box" id="Qry_area_s" size="6" maxlength="6">
# 					<span class="search_text">~</span>
# 					<input name="Qry_area_e" type="text" class="search_box" id="Qry_area_e" size="6" maxlength="6">
# 					<input name="unit" type="radio" class="search_td_up" id="unit"    value="1"><span class="search_text">m2</span>
# 					<input name="unit" type="radio" class="search_td_up" id="unit" checked value="2"><span class="search_text">坪</span>
# 				</td>
#
# 			</tr>
# 		</table></td>
# 	</tr>
# 	</form>
#
# <script type="text/javascript">
# $('#search_1').bind('click',search_on);
#
# $('#Qry_pattern').poshytip({
# 	className: 'tip-yellowsimple',
# 	showOn: 'focus',
# 	alignTo: 'target',
# 	alignX: 'inner-left',
# 	offsetX: -40,
# 	offsetY: 5,
# 	showTimeout: 100
# });
# </script>
#
#
#  <!--查詢條件-->
#         </table></td>
#       </tr>
#     </table>
#
#
#
# <!--  ================================資訊訊息面版==========================  -->
#     <div id="msg_panel" class="rc_hide">
# 		<table  border="0" cellpadding="0" cellspacing="0" style=" background-color: #C7EFA1; font-size: 16px; height: 24px;font-weight: bold;">
# 			<tr><td width="5%">&nbsp;&nbsp;</td>
# 				<td id="rc_msg" style=" valign: center; "></td>
# 				<td width="5%">&nbsp;&nbsp;</td>
# 			</tr>
# 		</table>
# 	</div>
# <!--  ================================選項顯示提示訊息面版==========================  -->
#     <div id="info_panel" class="rc_hide">
# 		<table border="0" cellpadding="0" cellspacing="0">
# 			<tr>
# 				<td><img src="/INC/images/msg2_01.gif" alt=" "></td>
# 				<td style="background-image: url(/INC/images/msg2_02.gif);" ><div id="info_panel_" style="margin-top: 9px; font-size: 14px;"></div></td>
# 				<td><img src="/INC/images/msg2_04.gif" alt=" "></td>
# 			</tr>
# 		</table>
# 	</div>
#
# <div id="rc_info_panel"  style="display:none">
# 	<div id="rc_info_content1">
# 	<div class="rc_left_tab_content">
# 		<div id="rc_info_content" style="height: 300px;">
# 			<table width="100%" border="0" cellspacing="0" cellpadding="0">
# 		    <tr><td>&nbsp;</td></tr>
# 			</table>
# 		</div>
# 		<div id="rc_info_content3" class="rc_hide"></div>
# 	</div>
# 	</div>
# 	<div id="rc_info_content2" class="description_color" style="line-height: 20px; font-size: 13px;"></div>
# </div>
#  <!--訊息面版  -->
#   </div><!-- end .header -->
# <form id="MenuForm" name="MenuForm">
# 	<input type="hidden"  id="in_type"  name = "in_type" value=""   >
# </form>
#   <div class="sidebar" id= "rc_leftup_tab_content" >
#
#
#     <table width="100%" border="0" cellpadding="0" cellspacing="0">
# <!--
#       <tr>
#         <td ><table width="100%" border="0" cellpadding="0" cellspacing="0">
#           <tr>
# 						<td align="center">
# 							<div class="submenu_tools_right" id="normal_tools_frame" onclick="checkMapDrawMode();changeToolImg('normal_tools_img_frame');" onkeypress="checkMapDrawMode();" >
# 								<img src="/INC/images/box.png" id="normal_tools_img_frame" name="frame" title= "框選查詢" alt="框選查詢"  /><div style="display: none;">框選查詢</div>
# 							</div>
# 						</td>
# 						<td align="center">
# 							<div class="submenu_tools_right" id="normal_tools_choose" >
# 								<img src="/INC/images/circle.png" id="normal_tools_img_choose" name="choose" class="choose"  title= "圈選查詢"  alt= "圈選查詢" onclick="run_choose(this.id, 280,250); changeToolImg('normal_tools_img_choose');toggleControl('none');$('#dialog').jqmHide();$('#map_show').jqmHide();" /><div style="display: none;">圈選查詢</div>
# 							</div>
# 						</td>
#           </tr>
# 					</table>
#         </td>
#       </tr>
# -->
#       <tr>
#         <td class="tools"><table width="100%" border="0" cellpadding="0" cellspacing="0">
#           <tr>
#             <td align="center">
# 							<div id="normal_tools_zoomin" class="submenu_tools_right" onclick="map.zoomIn();showMessage('放大地圖','msg_panel',1000);" onkeypress="map.zoomIn();showMessage('放大地圖','msg_panel',1000);">
# 							<img src="/INC/images/zoomin.png" id="normal_tools_img_zoomin" name="zoom in" title= "放大地圖" alt="放大地圖" /><div style="display: none;">放大</div>
# 						</div>
# 					</td>
#             <td align="center">
#
#     				<div id="normal_tools_zoomout" class="submenu_tools_right" onclick="map.zoomOut();showMessage('縮小地圖','msg_panel',1000);" onkeypress="map.zoomOut();showMessage('縮小地圖','msg_panel',1000);">
#     			<img src="/INC/images/zoomout.png" id="normal_tools_img_zoomout" name="zoom out"  title= "縮小地圖" alt="縮小地圖" /><div style="display: none;">縮小</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_hand" onclick="changeToolImg('normal_tools_img_hand');toggleControl('none');showMessage('瀏覽模式','msg_panel',3000);$('#frame').attr('checked', false);"  onkeypress="changeToolImg('normal_tools_img_hand');toggleControl('none');showMessage('瀏覽模式','msg_panel',3000);$('#frame').attr('checked', false);">
#     			<img src="/INC/images/hand_choose.png" id="normal_tools_img_hand" name="hand" title= "瀏覽模式"   alt="瀏覽模式"  /><div style="display: none;">瀏覽模式</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_area" onclick="changeToolImg('normal_tools_img_area');toggleControl('polygon');showMessage('面積量測模式：連點兩下可結束量測動作','msg_panel',3000);$('#frame').attr('checked', false);"  onkeypress="changeToolImg('normal_tools_img_area');toggleControl('polygon');showMessage('面積量測模式：連點兩下可結束量測動作','msg_panel',3000);$('#frame').attr('checked', false);" >
#     			<img src="/INC/images/area_choose.png" id="normal_tools_img_area" name="area" title= "面積量測" alt="面積量測"   /><div style="display: none;">面積量測</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_distance" onclick="changeToolImg('normal_tools_img_distance');toggleControl('line');showMessage('距離量測模式：連點兩下可結束量測動作','msg_panel',3000);$('#frame').attr('checked', false);" onkeypress="changeToolImg('normal_tools_img_distance');toggleControl('line');showMessage('距離量測模式：連點兩下可結束量測動作','msg_panel',3000);$('#frame').attr('checked', false);">
#     			<img src="/INC/images/distance_choose.png" id="normal_tools_img_distance" name="distance" title= "距離量測" alt="距離量測"     /><div style="display: none;">距離量測</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_select" onclick="changeToolImg('normal_tools_img_select');toggleControl('none');mapPointQuery('on');showMessage('點選查詢：於地圖上點選定位點，可查得其交易資料','msg_panel',3000);$('#frame').attr('checked', false);" onkeypress="changeToolImg('normal_tools_img_select');toggleControl('none');mapPointQuery('on');showMessage('點選查詢：於地圖上點選定位點，可查得其交易資料','msg_panel',3000);$('#frame').attr('checked', false);">
#     			<img src="/INC/images/select_choose.png" id="normal_tools_img_select" name="select" title= "點選查詢" alt="點選查詢"  /><div style="display: none;">點選查詢</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_mapclass" >
# 				<!--
#     			<img src="/INC/images/map_on.png" class="mapbtna" id="normal_tools_img_mapclass" name="map_class" title= "地圖模式" alt= "地圖模式"   onclick="run_map_show(this.id, 280,210);$('#dialog').jqmHide();$('#choose').jqmHide();"  onkeypress="run_map_show(this.id, 280,210);$('#dialog').jqmHide();$('#choose').jqmHide();" /><div style="display: none;">地圖模式</div>
# 				-->
#     			<img src="/INC/images/map_on.png" class="mapbtna" id="normal_tools_img_mapclass" name="map_class" title= "地圖模式" alt= "地圖模式"   /><div style="display: none;">地圖模式</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_pos"  >
#     			<img src="/INC/images/locate_on.png" class="btna"  id="normal_tools_img_pos" name="pos"  title= "定位"  alt= "定位" onclick="run_dialog(this.id, 260, 180);$('#choose').jqmHide();changeCountry('city');" onkeypress="run_dialog(this.id, 260, 180);$('#choose').jqmHide();changeCountry('city');" /><div style="display: none;">定位</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_frame" onclick="checkMapDrawMode();changeToolImg('normal_tools_img_frame');" onkeypress="checkMapDrawMode();changeToolImg('normal_tools_img_frame');" >
#     			<img src="/INC/images/frame.png" id="normal_tools_img_frame" name="frame" title= "框選查詢:以矩形方式來選取查詢範圍。" alt="框選查詢"   /><div style="display: none;">框選查詢</div>
#     		</div>
# 			</td>
#             <td align="center">
#     		<div class="submenu_tools_right" id="normal_tools_choose" >
#     			<img src="/INC/images/choose.png" id="normal_tools_img_choose" name="choose" class="choose"  title= "圈選查詢：選取半徑2.5公里/5公里及點選位置。"  alt= "圈選查詢" onclick="run_choose(this.id, 280,250); changeToolImg('normal_tools_img_choose');toggleControl('none');$('#dialog').jqmHide();" onkeypress= "run_choose(this.id, 280,250); changeToolImg('normal_tools_img_choose');toggleControl('none');$('#dialog').jqmHide();"/><div style="display: none;">圈選查詢</div>
#     		</div>
# 			</td>
#
#           </tr>
# 		  <input type="hidden"  id="frame_select"  value="off"   >
# 		  <input type="hidden"  id="circle_select"  value="off"   >
# 		  <input type="hidden"  id="nlsccnt"  value="">
#         </table></td>
#       </tr>
#
#
# <script type="text/javascript">
# $('#normal_tools_img_frame').each(function() {
#     var linkid = $(this).attr("id");
# 		var tooltip =$(this).attr("title");
#     $(this).poshytip({
#         content: function(updateCallback) {
#             return tooltip;
#         },
# 				alignTo: 'target',
# 				alignX: 'inner-left',
# 				offsetX: -15,
# 				offsetY: 5
#     });
#
# }).poshytip('show');
#
# $('#normal_tools_img_choose').each(function() {
#     var linkid = $(this).attr("id");
# 		var tooltip =$(this).attr("title");;
#     $(this).poshytip({
#         content: function(updateCallback) {
#             return tooltip;
#         },
# 				alignTo: 'target',
# 				alignX: 'inner-left',
# 				alignY: 'bottom',
# 				offsetX: -15,
# 				offsetY: 5
#     });
#
# }).poshytip('show');
# 	var map_s ="";
# $('#normal_tools_img_mapclass').poshytip({
# 	className: 'tip-yellowsimple',
# 	alignTo: 'target',
# 	alignX: 'inner-left',
# 	alignY: 'bottom',
# 	offsetX: -50,
# 	offsetY: 5,
# 	content: function(updateCallback) {
# 			var map_type = $('#MAP_TYPE').val();
# 			var togs ="";
# 			var nlsc ="";
# 			var osm ="";
# 			var gmap ="";
# 			if(map_type=="tgos"){
# 					togs = "checked";
# 					map_s= "T";
# 			}
# 			else if(map_type=="nlsc"){
# 					nlsc = "checked";
# 					map_s= "N";
# 			}
# 			else if(map_type=="gmap"){
# 					gmap = "checked";
# 					map_s= "G";
# 			}
# 			else{
# 					osm = "checked";
# 					map_s= "O";
# 			}
#
# 		return "<table><tbody><tr><td><input type='radio' id='mapid' name='mapid'  onclick=chgmapmode(tgos,'T'); "+togs+" value='tgosid'> <label for='rd_bk'>TGOS地圖</label></td></tr><tr><td><input type='radio' id='mapid' name='mapid'  onclick=chgmapmode(nlsc,'N'); "+nlsc+" value='nlscid'> <label for='rd_bk'>NLSC地圖</label></td></tr><tr><td><input type='radio' id='mapid' name='mapid'  onclick=chgmapmode(osm,'O');  "+osm+" value='osmid'> <label for='rd_bk'>OSM地圖</label></td></tr></tbody></table>";
#
# //<tr><td>Google地圖</td></tr><tr><td>&nbsp;&nbsp;&nbsp;<input type='radio' id='mapid' name='mapid'  onclick=chgmapmode(gmap,'G');  "+gmap+" value='gmapid'> <label for='rd_bk'>電子地圖</label></td></tr><tr><td>&nbsp;&nbsp;&nbsp;<input type='radio' id='mapid' name='mapid'  onclick=chgmapmode(ghyb,'G');  "+ghyb+" value='ghybid'> <label for='rd_bk'>混合地圖</label></td></tr>
# 	},
# 	showTimeout: 100
# });
#
# //切換地圖時送出統計 G--> google map ,T-->TGOS,N-->NLSC中辦,O-->OSM
# function chgmapmode(mapmode,msp_e){
# 	map.setBaseLayer(mapmode);
# 	if(map_s != msp_e){
# 		$.ajax({
# 			url: './MapInfo_send.action',
# 			type: "POST",
# 			dataType : "json",
# 			data : { map_s:map_s,map_e: msp_e
# 			},
# 			success: function(json) {
# 				if(json.result=="SUCCESS"){
#
# 				}
# 			}
# 		});
# 	}
# }
#
#
# </script>
#  <!--工具列  -->
#       <tr>
#         <td class="map"  ><!--地圖  -->
# 			<div class="contain_left"  id = "map" >
# 			    <script type="text/javascript">switchRightComponent(true);</script>
# 				<div id="map_openlayers" ></div>
# 			   <div id="sys_panel" style="display:none;"></div>
#
# 			   <span id="nlsc_copyright" style="display:none;>"><a  href="http://maps.nlsc.gov.tw" target="_new"><img src="http://maps.nlsc.gov.tw/O09/images/copyright.png" style="position:absolute; left:10; bottom:0; z-index:9999;}" alt="nlsc地圖"></img></a></span>
# 			</div>
# 			<input type="hidden"  id="MAP_TYPE"  name = "MAP_TYPE" value="osm"   >
# 	  		<input type="hidden"  id="intype"  name = "intype" value="land"   >
# 		</td>
#       </tr>
#     </table>
#   </div>
#   <div class="content">
#     <!-- end .content -->
#     <div id="tabcontrol" >
#       <table width="5%" border="0" cellspacing="0" cellpadding="0">
#         <tr>
#           <td><p>
#     		<div class="submenu_tools_right" id="normal_tools_close" onclick="folder('rc_leftup_tab_content','normal_tools_img_close');" onkeypress="folder('rc_leftup_tab_content','normal_tools_img_close');">
#     			<img src="/INC/images/close_on.gif" id="normal_tools_img_close" name="close" alt = '收合按鈕' /> <!--收合按鈕  -->
# 		  </td>
#         </tr>
#         <tr>
#           <td><img src="/INC/images/label_green.jpg" width="2" height="400" alt = ' '/></td>
#         </tr>
#       </table>
#     </div>
#     <div id="rc_datacontent">
#
# <div><!-- end .header -->
#   <div id = "qr_notice"  class="qr_notice" style="display:none;" >
#     <!-- end .qr_notice -->
#     <table border="0"  cellspacing="0" cellpadding="0">
#       <tr>
#         <td class="qr_notice_title">&nbsp;</td>
#       </tr>
#       <tr>
#         <td class="qr_notice_content"><table border="0" cellspacing="0" cellpadding="0">
# 		  <tr>
#             <td class="qr_text_number">1.</td>
#             <td class="qr_text">網站最佳瀏覽效果建議請使用Chrome瀏覽器。</td>
#           </tr>
#           <tr>
#             <td class="qr_text_number">2.</td>
#             <td class="qr_text">若使用IE瀏覽器，請使用IE8(含)以上之版本。</td>
#           </tr>
#           <tr>
#             <td class="qr_text_number">3.</td>
#             <td class="qr_text">本網站文件提供.pdf格式,須搭配免費下載之AdobeReader閱讀軟體使用。</td>
#           </tr>
#         </table></td>
#       </tr>
#       <tr>
#         <td class="qr_notice_end"></td>
#       </tr>
#     </table>
#   </div>
#   <div class="qr_content"><img src="/INC/images/qr_title.gif" alt=" ">
#     <div id="TabbedPanels1" class="TabbedPanels">
#       <ul class="TabbedPanelsTabGroup">
#         <li class="TabbedPanelsTab" tabindex="34" onkeypress="TabbedPanels1.showPanel(0);" ><a  href="#"   >查詢功能</a></li>
#         <li class="TabbedPanelsTab" tabindex="35" onkeypress="TabbedPanels1.showPanel(1);"><a  href="#">圖形控制</a></li>
#         <li class="TabbedPanelsTab" tabindex="36" onkeypress="TabbedPanels1.showPanel(2);"><a  href="#">查詢流程</a></li>
#         <li class="TabbedPanelsTab" tabindex="37" onkeypress="TabbedPanels1.showPanel(3);"><a  href="#">地圖模式</a></li>
#         <li class="TabbedPanelsTab" tabindex="37" onkeypress="TabbedPanels1.showPanel(4);"><a  href="#">下&nbsp;載</a></li>
#       </ul>
#       <div class="TabbedPanelsContentGroup"  >
#         <div class="TabbedPanelsContent" >
# 				  <div class="qr_content_data" >
#           <table border="0" cellpadding="0" cellspacing="0" hspace="2" vspace="2"  >
#             <tr>
#               <td colspan="2" class="titlewa" ><strong>　　◆條件查詢區（上方）： 　輸入選擇查詢條件，點選搜尋進行資料查詢。</strong></td>
#             </tr>
#             <tr>
#               <td width="18">&nbsp;</td>
#               <td class="titlewa" ><ol>
#                 <li>縣市區域：依查詢條件選擇該縣市及區域。<font color="#CC0000"><strong>*(必選)</strong></font></li>
#                 <li>建物型態：選擇查詢建物類型。</li>
#                 <li>交易期間：依查詢條件選擇交易期間。</li>
#                 <li>道路名稱：依選取縣市及鄉鎮市區，輸入任意字數可搜尋相關路名。</li>
#                 <li>不動產類別：依查詢條件選擇類別，包括房地(土地+建物)、房地(土地+建物)+車位、土地、建物、車位。</li>
#                 <li>圖台框選範圍：選取縣市區域（必填），並勾選至少一種建物型態，即可於圖台上框選範圍進行搜尋作業。</li>
#                 <li>交易總價：依查詢條件設定交易總價範圍，以『萬元』為單位。</li>
#                 <li>交易單價：依查詢條件設定交易單價範圍，以『萬元』為單位。</li>
#                 <font color="#CC0000"><strong>注：查詢結果，建物型態為透天厝、農舍、工廠、倉庫或車位者不顯示單價。</strong></font>
#                 <li>移轉總面積：依查詢條件設定交易標的面積範圍，可以『坪』或『m&sup2;』為單位。</li>
#                 <li>搜尋範圍均價計算：利用搜尋條件的資料中，將此範圍做完整的運算並取出範圍平均的價格。</li>
#                 <font  color="#CC0000"><strong>注：均價查詢功能，建物型態為透天厝、農舍、工廠、倉庫或車位者不納入均價計算。</strong></font>
#                 <li>使用分區：根據都市土地/非都市土地，依其使用計畫劃定不同的使用分區類別作為過濾條件進行查詢。</li>
#                 <li>建物格局：以輸入建物格局代碼方式作為過濾條件，如『3房2廳2衛有隔間』，為『3/2/2/Y』。</li>
#                 <li>搜尋：利用搜尋條件的資料，比對出符合之物件。<br />
#                 </li>
#               </ol></td>
#             </tr>
#             <tr>
#               <td colspan="2" class="titlewa"><strong>　　◆檢索結果區（右下）： 　依搜尋結果，顯示符合條件物件資料區。</strong></td>
#             </tr>
#             <tr>
#               <td>&nbsp;</td>
#               <td width="552" class="titlewa" ><ol>
#                 <li>查詢結果每1頁顯示10筆。</li>
#                 <li>輸入驗證碼後，可查詢次數為40次，可使用時間為60分鐘。</li>
#               </ol></td>
#             </tr>
#             <tr>
#               <td colspan="2" class="titlewa" ><strong>　　◆圖形控制區（左下）：　依搜尋結果，以圖形顯示區域及範圍。</strong></td>
#             </tr>
#           </table>
#         </div>
#         </div>
#         <div class="TabbedPanelsContent">
# 				  <div class="qr_content_data" >
#           <table class="new_table" border="1" style="margin-top:2em" >
#             <tr class="titlewa">
#               <td width="64"  style="text-align: center">功能圖示</td>
#               <td width="64"  style="text-align: center"><div align="center">功能名稱</div></td>
#               <td width="420">說明</td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/1.png" width="26" height="27" /></td>
#               <td style="text-align: center">放大</td>
#               <td style="text-align:left">畫面放大，點選一次放大一次。</td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/2.png" width="29" height="27" /></td>
#               <td style="text-align: center">縮小</td>
#               <td style="text-align:left">畫面縮小，點選一次縮小一次。</td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/3.png" width="26" height="27" /></td>
#               <td style="text-align: center">平移拖動</td>
#               <td style="text-align:left">可上下左右平移視景。</td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/4.png" width="28" height="27" /></td>
#               <td style="text-align: center">面積量測</td>
#               <td style="text-align:left">點選後，在地圖上以連續左鍵點選取得區域範圍，連點左鍵二下結束。 </td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/5.png" width="28" height="27
#               " /></td>
#               <td style="text-align: center">距離量測</td>
#               <td style="text-align:left">點選後，在地圖上以連續左鍵點選取得距離長度，連點左鍵二下結束。 </td>
#             </tr>
#             <tr>
#               <td style="text-align: center"><img src="/INC/images/6.png" width="30" height="27" /></td>
#               <td style="text-align: center">點選查詢</td>
#               <td style="text-align:left">針對查詢出範圍內的資料，直接在圖上點選<img src="/INC/images/ipoint.png" alt="" width="27" height="24" align="absmiddle" />反查。</td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/frame.png" width="24" height="24" /></td>
#               <td style="text-align: center">框選查詢</td>
#               <td style="text-align:left">以矩形方式來選取查詢範圍。(只可以跨鄉鎮市區的查詢)</td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/choose.png" width="24" height="24
#               " /></td>
#               <td style="text-align: center">圈選查詢</td>
#               <td style="text-align:left">以圓形方式來選取查詢範圍，選擇為 2.5公里／5公里的範圍後，點選地圖上位置查詢。(只可以跨鄉鎮市區的查詢)</td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align: center"><img src="/INC/images/9.png" width="35" height="27" /></td>
#               <td style="text-align: center">地圖模式</td>
#               <td style="text-align:left">切換地圖顯示種類（NLSC地圖/OSM地圖/TGOS地圖）。</td>
#             </tr>
#             <tr class="titlewa">
#               <td rowspan="5" style="text-align: center"><div align="center"><img src="/INC/images/10.png" width="30" height="29" /></div></td>
#               <td rowspan="5" style="text-align: center">定位</td>
#               <td style="text-align:left">1.門牌定位：
#                 使用者輸入要定位之門牌號後，系統即以該門牌號，標示該門牌所在位置於圖上。 </td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align:left">2.村里定位：
#                 使用者依序輸入縣市、鄉鎮市區及村里後，圖形區立即定位至該村里位置，並於圖上套疊村里界圖。 </td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align:left">3.路口定位：
#                 提供交叉路口定位功能，使用者選擇了某一縣市鄉鎮市區之某一道路時（路口一），系統自動列表顯示有相交之道路（路口二）供使用者選取定位。 </td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align:left">4.地標定位：
#                 使用者選取大類別後，再列出該類別所包含小類別，並進一步列出小類別中所有地標資料供選取定位。 </td>
#             </tr>
#             <tr class="titlewa">
#               <td style="text-align:left">5.坐標定位：
#                 由使用者輸入經、緯度坐標，直接改變地圖顯示位置。</td>
#             </tr>
#           </table>
#         </div>
#         </div>
#         <div class="TabbedPanelsContent">
# 				  <div class="qr_content_data" >
#           <div class="CollapsiblePanelContent">
#             <p style="margin-top: 2em; text-align: left;" class="titlewa"><font color="#CC0000" ></font><font color="#CC0000" >以下以不動產買賣功能為例</font></p>
#             <ol class="titlewa">
#               <li>選擇『不動產買賣』，依所需查詢範圍的條件，逐一選擇輸入後，按下搜尋按鈕。</li>
#               <li>系統依查詢條件會將搜尋出的圖文結果，顯示在下方。右邊為對應的資料明細顯示區，左邊為對應的圖形區。　　　　　　　</li>
#               <li>查詢出結果，可依使用者需求設定條件排序大小。<img src="/INC/images/order.png" width="101" height="80" style="border:thin dashed #D9D9D9" align="top" alt="step3" /></li>
#               <li>亦可使用圖形控制工具量測距離或面積等功能。</li>
#               <li>點選明細資料中的交易明細，即會顯示該筆交易標的相關資料</li>
#                         <span style="text-align: justify"></span><img src="/INC/images/step3.jpg" alt="step5" width="357" height="312" style="margin:2em 0" /></ol></div>
#         </div>
#         </div>
#         <div class="TabbedPanelsContent">
# 				  <div class="qr_content_data" >
#
# 				<table>
# 					<tr class="titlewa">
# 						<td width="52" valign="top">（一）</td>
# 						<td width="506" > <p>TGOS地圖:為地理資訊圖資雲服務平台所提供之電子地圖，融合交通部之路網數值圖與國土測繪中心之通用版電子地圖製作, 詳細說明請參考<a href="#" onClick="window.open('http://tgos.nat.gov.tw/tgos/Web/TGOS_Home.aspx');">http://tgos.nat.gov.tw</a>。 </p>
# 					    <p><img src="/INC/images/map_tgos.png"  /></p></td>
# 					</tr>
# 					<tr class="titlewa">
# 						<td valign="top">（二）</td>
# 						<td ><p>NLSC地圖:為國土測繪中心所建置之「國土測繪圖資網路地圖服務」所提供之通用版電子地圖、通用版正射影像及混合地圖(通用版電子地圖向量+正射影像), 詳細說明請參考<a href="#" onClick="window.open('http://maps.nlsc.gov.tw');">http://maps.nlsc.gov.tw</a>。
# 						</p>
# 					    <p><img src="/INC/images/map_nlsc.png" /></p></td>
# 					</tr>
# 					<tr class="titlewa">
# 						<td width="52" valign="top">（三）</td>
# 						<td width="506" > <p>OSM地圖:為OpenStreetMap (開放街圖，簡稱OSM) 是自由而且開源的全球地圖, 詳細說明請參考<a href="#" onClick="window.open('http://openstreetmap.tw/');">http://openstreetmap.tw/</a>。 </p>
# 					    <p><img src="/INC/images/map_osm.png"/></p></td>
# 					</tr>
# <!-- 					<tr class="titlewa">
# 						<td width="52" valign="top">（四）</td>
# 						<td width="506" > <p>Google地圖:為Google Maps所提供之電子地圖、衛星影像及混合地圖(衛星影像+路網)，完畢後按「x」退出。 </p>
# 					    <p><img src="/INC/images/map4.jpg" /></p></td>
# 					</tr> -->
# 				</table>
# 				</div>
# 				</div>
#         <div class="TabbedPanelsContent">
# 		<table>
# 			<tr class="titlewa">
# 				<td >（一）</td>
# 				<td >提供使用者「Android版」下載。<a  href="INC/download/G_N11.apk"><img src="/INC/images/download_02.png" name="apk" alt="下載手機app"   border="0" class="area_space" id="apk" /></a>
# 				</td>
# 			</tr>
# 			<tr class="titlewa">
# 				<td >（二）</td>
# 				<td >提供使用者「不動產交易實價查詢服務網系統使用手冊.pdf」下載。<a  href="INC/download/N11_Operation.pdf" ><img src="/INC/images/download_02.png" name="userpdf"   alt="下載系統使用手冊.pdf"   border="0" class="area_space" id="userpdf" /></a>
# 				</td>
# 			</tr>
# 			<tr class="titlewa">
# 				<td >（三）</td>
# 				<td >提供使用者「AdobeReader閱讀軟體」下載。<a  href="INC/download/AdobeReader10_tw.exe" ><img src="/INC/images/download_02.png" name="AdobeReader"   alt="下載AdobeReader閱讀軟體" border="0" class="area_space" id="AdobeReader" /></a>
# 				</td>
# 			</tr>		</table>
# 		</div>
#       </div>
#     </div>
# </div>
# <!-- end .container --></div>
# <script type="text/javascript">
# var TabbedPanels1 = new Spry.Widget.TabbedPanels("TabbedPanels1");
# </script> <!--未查詢-->
#     </div>
#
# <div id ='footer' class="footer"><span class="qr_pipmoi">住宅存量資訊，請至<a href="http://pip.moi.gov.tw"  target="_blank"><font color="#0000FF"><U>內政部不動產資訊平台</U></font></a>之住宅資訊動態看板參閱</span><p>本系統建議最佳瀏覽器採用 FireFox、Chrome、Opera<br>
#
#   不動產實價查詢服務專線：1996(免付費電話)，為民服務時間：<br>週一至週五08:00~17:30。電子郵件信箱:<a href='mailto:q11@quantasoft.com.tw?subject=%E5%85%A7%E6%94%BF%E9%83%A8%E4%B8%8D%E5%8B%95%E7%94%A2%E4%BA%A4%E6%98%93%E5%AF%A6%E5%83%B9%E6%9F%A5%E8%A9%A2%E6%9C%8D%E5%8B%99%E7%B3%BB%E7%B5%B1%E6%84%8F%E8%A6%8B%E5%BB%BA%E8%AD%B0&oq=%E5%85%A7%E6%94%BF%E9%83%A8%E4%B8%8D%E5%8B%95%E7%94%A2%E4%BA%A4%E6%98%93%E5%AF%A6%E5%83%B9%E6%9F%A5%E8%A9%A2%E6%9C%8D%E5%8B%99%E7%B3%BB%E7%B5%B1%E6%84%8F%E8%A6%8B%E5%BB%BA%E8%AD%B0' >q11@quantasoft.com.tw</a>。
# </div>
#   </div>
#   <div id="print_panel" style="display:none;">
#
# <div id="tbl_show_point" >
# <table width="100%" border="0" cellspacing="0" cellpadding="0">
# 	<tr><td style="font-size: 22px; height: 10px;font-weight: bold;" colspan="6" align="center">內政部地政司  不動產交易實價查詢結果</td></tr>
# </table>
# <table width="100%" border="1" cellspacing="0" cellpadding="0" id="point_showlist_tbl" >
# </table>
# </div>
#
# </div>
# <!-- end .container --></div>
#
# <script>
# $(function() {
# 	 $( "#showalert" ).dialog({
# 		autoOpen: false,
# 		height: 330,
# 		width: 430,
# 		modal: true,
# 		buttons: {
# 			"取消提醒": function() {
# 				$( this ).dialog( "close" );
# 				$.post('./pro/setRemark.jsp');
# 			}
# 		}
# 	});
#
# 	 $( "#showalert2" ).dialog({
# 		autoOpen: false,
# 		height:580,
# 		width: 430,
# 		modal: true,
# 		buttons: {
# 			"取消提醒": function() {
# 				$( this ).dialog( "close" );
# 				$.post('./pro/setRemark.jsp');
# 			}
# 		}
# 	});
#
# 		$( "#showMsg" ).dialog({
# 			autoOpen: false,
# 			height: 240,
# 			width: 350,
# 			modal: true,
# 			buttons: {
# 				"確定": function() {
# 					$( this ).dialog( "close" );
# 				}
# 			}
# 		});
#
#
# });
#
# </script>
# <style type="text/css">
# .important_alert {
# 	text-decoration:underline;
# 	color: red;
# 	padding-left:20pt;
# 	padding-top:1pt;
# 	padding-bottom:1pt;
# 	margin:1pt;
# 	font-weight:bold;
# }
# .important_title {
# 	padding-left:1pt;
# 	padding-top:1pt;
# 	padding-bottom:1pt;
# 	margin:1pt;
# 	font-weight:bold;
# }
# </style>
# </head>
# <div id="showalert" title="系統提醒" style="display:none">
# 	    <div class="important_title">提醒民眾及房仲業者</div>
# 		<div class="important_alert">民眾委託房仲業者買賣房屋宜先商議服務費額</div>
# 	不動產仲介經紀業服務報酬之計收，主管機關並未規定<br/>
# 	固定收費比率，消費者可與房仲業者自行議訂，其向買<br/>
# 	賣或租賃之一方或雙方收取報酬之總額，合計不得超過<br/>
# 	該不動產實際成交價金6%或1.5個月租金。<br/>
# 	<br/>
# <fieldset><p>不動產成交價格(金)因異質性影響，即使同一棟亦存在價差，查詢所得資訊不代表該區域內所有不動產行情。</p></fieldset>
# </div>
#
# <div id="showalert2" title="系統提醒" style="display:none">
# </div>
#
# <div id="showMsg" title="提示" style="display:none">
#     <p><span id = 'Msgtext'></span></p>
#
# </div>
#  <!--未查詢-->
#
#
#
# <script type="text/javascript" src="/INC/js/jqModal.js"></script>
# <script>
# function run_dialog(source, top, left){
#   var pos = $(".sidebar").position();
#  	$("#dialog").css("display", "none");
#  	$("#dialog").css("position", "absolute");
# 	$("#dialog").css("left", pos.left+20 );
# 	$("#dialog").css("top",  pos.top+20 );
# 	$("#dialog").css("width", "auto" );
#
#   $(function() {
# 	$("#dialog").jqm({
# 		trigger:'.btna',
# 		modal:true
# 	   }
# 	);
# 	})
# }
#   $(function() {
# 	$("#dialog").jqm({
# 		trigger:'.btna',
# 		modal:true
# 	   }
# 	);
# 	})
#
#
#
# //function run_map_show(source, top, left){
# //  var pos = $(".sidebar").position();
# //  	$("#map_show").css("position", "absolute");
# //	$("#map_show").css("left",pos.left+20 );
# //	$("#map_show").css("top",  pos.top+30  );
# //	$("#map_show").css("width", "auto" );
# //  $(function() {
# //	$("#map_show").jqm({
# //		trigger:'.mapbtna',
# //		modal:true
# //	   }
# //	);
# //	})
# //}
# //  $(function() {
# //	$("#map_show").jqm({
# //		trigger:'.mapbtna',
# //		modal:true
# //	   }
# //	);
# //	})
#
# function run_frame(source, top, left){
#   var pos = $(".sidebar").position();
#   	$("#tools_frame").css("position", "absolute");
# 	$("#tools_frame").css("left",pos.left+20 );
# 	$("#tools_frame").css("top", pos.top+30 );
# 	$("#tools_frame").css("width", "auto" );
#   $(function() {
# 	$("#tools_frame").jqm({
# 		trigger:'.tools_frame',
# 		modal:true
# 	   }
# 	);
# 	})
# }
#   $(function() {
# 	$("#tools_frame").jqm({
# 		trigger:'.tools_frame',
# 		modal:true
# 	   }
# 	);
# 	})
# function run_choose(source, top, left){
#   var pos = $(".sidebar").position();
#   	$("#choose").css("position", "absolute");
# 	$("#choose").css("left", pos.left+20 );
# 	$("#choose").css("top",   pos.top+30 );
# 	$("#choose").css("width", "auto" );
#   $(function() {
# 	$("#choose").jqm({
# 		trigger:'.choose',
# 		modal:true
# 	   }
# 	);
# 	})
# }
#   $(function() {
# 	$("#choose").jqm({
# 		trigger:'.choose',
# 		modal:true
# 	   }
# 	);
# 	})
# </script>
# <style type="text/css">
# <!--
#
# .talk_box{ width:320px; margin:0 ; padding:20px 0px 20px 20px;line-height:180%; border:2px solid #E6CA29;}
# .talk_p1{ color:#009944; padding:0 0 0px 20px; font-family: DFKai-sb; font-size:20px; font-weight:bold;}
# .talk_p2{ color:#1d2088;padding:0 0 15px 20px;}
# .talk_p3{ color:#a40000;padding:0 0 15px 50px;}
# * iframe.jqm {position:absolute;top:0;left:0;z-index:-1;
# 	width: expression(this.parentNode.offsetWidth+'px');
# 	height: expression(this.parentNode.offsetHeight+'px');
# }
# * html .jqmWindow {
#      position: absolute;
#      top: expression((document.documentElement.scrollTop || document.body.scrollTop) + Math.round(17 * (document.documentElement.offsetHeight || document.body.clientHeight) / 100) + 'px');
# }
# -->
# </style>
# <div id="dialog" class="jqmWindow" style="display:none">
# 	<div align="right" >&nbsp;
# 	</div>
# 	<table  width='100%' border="0" cellpadding="0" cellspacing="0" class="table_bg">
# 	  <tr>
# 		<td><div id="TabbedPanels1" class="TabbedPanels">
# 		  <ul class="TabbedPanelsTabGroup">
# 			<li class="TabbedPanelsTab" id ="img_normal_numbers"  style="background-image: url(/INC/images/green2_bg.gif);"><a  href="#door" onclick="addSubMenu('.submenu_pos','./pro/pos_door.jsp','img_normal_numbers','green2_bg.gif')" onkeypress="addSubMenu('.submenu_pos','./pro/pos_door.jsp','img_normal_numbers','green2_bg.gif')">門牌定位</a></li>
# 			<li class="TabbedPanelsTab" id ="img_normal_village"><a  href="#village" onclick="addSubMenu('.submenu_pos','./pro/pos_village.jsp','img_normal_village','green2_bg.gif')" onkeypress="addSubMenu('.submenu_pos','./pro/pos_village.jsp','img_normal_village','green2_bg.gif')" >村里定位</a></li>
# 			<li class="TabbedPanelsTab" id ="img_normal_crossroads"><a  href="#crossroads" onclick="addSubMenu('.submenu_pos','./pro/pos_cross.jsp','img_normal_crossroads','green2_bg.gif')" onkeypress="addSubMenu('.submenu_pos','./pro/pos_cross.jsp','img_normal_crossroads','green2_bg.gif')">路口定位</a></li>
# 			<li class="TabbedPanelsTab" id ="img_normal_landmark"><a  href="#landmark" onclick="addSubMenu('.submenu_pos','./pro/pos_landmark.jsp','img_normal_landmark','green2_bg.gif')" onkeypress="addSubMenu('.submenu_pos','./pro/pos_landmark.jsp','img_normal_landmark','green2_bg.gif')">地標定位</a></li>
# 			<li class="TabbedPanelsTab" id ="img_normal_coord"><a  href="#coord" onclick="addSubMenu('.submenu_pos','./pro/pos_coord.jsp','img_normal_coord','green2_bg.gif');croodPosQryVal()" onkeypress="addSubMenu('.submenu_pos','./pro/pos_coord.jsp','img_normal_coord','green2_bg.gif');croodPosQryVal()">坐標定位</a></li>
# 			<li><img width="30" height="25" src="/INC/images/x.png"  alt="關閉" onclick="$('#dialog').jqmHide();" onkeypress="$('#dialog').jqmHide();"/>&nbsp;</a></li>
# 		  </ul>
# 		  <div class="TabbedPanelsContentGroup">
# 			<div class="TabbedPanelsContent">
# 				<div id="submenu_pos" class="submenu_pos" >
#
#
# <script type="text/javascript" >
# 	changeCountry("city");
# </script>
#
# <div>
#
# 	<div id="div_city" class="rc_form_float_left">
# 		<select id="city" onChange="changeArea('city','area_office');changeArea('city','Qry_area_office');$('#Qry_city').val($('#city').val());pos_city('city');" >
# 				<option value="">縣市</option>
# 		</select>
# 	</div>
# 	<div id="div_area" class="rc_form_float_left">
# 		<select id="area_office" onChange="checkRood('section');pos_area('city','area_office');" >
# 				<option value="">鄉鎮市區</option>
# 		</select>
# 	</div>
# 	<div id="div_road" class="rc_form_float_left">
# 	道路名稱：<input type="text" size="30" id="section" value='' >
# 	</div>
#
# 	<div id="div_number" class="rc_form_float_left">
# 		<input type="text" size="5" id="number_doorname" ></input>號
# 	</div>
# 	<div class="rc_form_float_left">
# 		<input type="button" id="div_doorname_query" value="定位" onclick="catchDoorInfo('city','area_office', 'section','number_doorname' , 'rc_info_content');$('#dialog').jqmHide();"
# 			 onkeypress="catchDoorInfo('city','area_office', 'section','number_doorname' , 'rc_info_content');$('#dialog').jqmHide();" >
# 	</div>
# </div>
#
#
# 				</div>
# 			</div>
# 		  </div>
# 		</div></td>
# 	  </tr>
# 	</table>
# </div>
#
# <div id="map_show" class="jqmWindow" style="display:none">
# 	<table  width='100%' border="0" cellpadding="0" cellspacing="0" class="table_bg">
# 	  <tr>
# 		<td><div id="TabbedPanels1" class="TabbedPanels">
# 		  <ul class="TabbedPanelsTabGroup">
#
# 			<li class="TabbedPanelsTab" tabindex="0" id="tgosid" style="background-image: url(/INC/images/white_bg.gif);" ><a  href="#" onclick="addMapMenu('tgosid','green2_bg.gif');change_maps('tgos');" >TGOS地圖</a></li>
#
# 			<li class="TabbedPanelsTab" tabindex="0" id="nlscid"  style="background-image: url(/INC/images/white_bg.gif);" ><a  href="#" onclick="addMapMenu('nlscid','green2_bg.gif');change_maps('nlsc');"  >NLSC地圖</a></li>
#
# 			<li class="TabbedPanelsTab" tabindex="0" id="osmid" style="background-image: url(/INC/images/white_bg.gif);" ><a  href="#" onclick="addMapMenu('osmid','green2_bg.gif');change_maps('osm');" >OSM地圖</a></li>
#
# 			<li class="TabbedPanelsTab" tabindex="0" id="gmapid" style="background-image: url(/INC/images/white_bg.gif);" ><a  href="#" onclick="addMapMenu('gmapid','green2_bg.gif');change_maps('gmap');" >Google地圖</a></li>
# 			<li ><img width="30" height="25" src="/INC/images/x.png"  alt="關閉"  onclick="$('#map_show').jqmHide();" /></li>
# 		  </ul>
# 		  <div class="TabbedPanelsContentGroup">
#
# 			<div id='tgos'  style="display:none"    class="TabbedPanelsContent">
# 			  <table border="0" cellspacing="0" cellpadding="0">
# 					<tr>
# 						<td align="center"><input type="radio" name="map_mode_tgos" onclick="checkmapmode(tgos,'TGOSMAP_W')"  checked />電子地圖</td>
# <!--
# 						<td align="center"><input type="radio" name="map_mode_tgos" onclick="checkmapmode(F2IMAGE_W,'F2IMAGE_W')"  />影像地圖</td>
# 						<td><input type="radio" name="map_mode_tgos" onclick="checkmapmode(ROADMAP_W,'ROADMAP_W')"/>混合地圖</td>
#   -->
# 					</tr>
# 			  </table>
# 			</div>
#
# 			<div id ='nlsc'  style="display:none"  class="TabbedPanelsContent">
# 			  <table  border="0" cellspacing="0" cellpadding="0">
# 				<tr>
# 				<td align="center"><input type="radio" name="map_mode_gt" onclick="checkmapmode(nlsc,'tw_00A')" onkeypress="checkmapmode(nlsc,'tw_00A')" checked />電子地圖</td>
# 				<td align="center"><input type="radio" name="map_mode_gt" onclick="checkmapmode(tw_96,'tw_96')"   onkeypress="checkmapmode(tw_96,'tw_96')" />影像地圖</td>
# 				<td align="center"><input type="radio" name="map_mode_gt" onclick="checkmapmode(tw_00B,'tw_00B')" onkeypress="checkmapmode(tw_00B,'tw_00B')" />混合地圖</td>
#  			</tr>
# 			  </table>
# 			</div>
#
# 			<div id ='osm'  style="display:none"  class="TabbedPanelsContent">
# 			  <table  border="0" cellspacing="0" cellpadding="0">
# 				<tr>
# 				<td align="center"><input type="radio" name="map_mode_osm" onclick="checkmapmode(osm,'OSM')" onkeypress="checkmapmode(osm,'OSM')" checked />電子地圖</td>
#  			</tr>
# 			  </table>
# 			</div>
# 			<div id='gmap'  style="display:none"  class="TabbedPanelsContent">
# 			  <table border="0" cellspacing="0" cellpadding="0">
# 				<tr>
# 				<td align="center"><input type="radio" name="map_mode" onclick="checkmapmode(gmap,'gmap')" onkeypress="checkmapmode(gmap,'gmap')" checked />電子地圖</td>
# 				<td align="center"><input type="radio" name="map_mode" onclick="checkmapmode(gsat,'gsat')" onkeypress="checkmapmode(gsat,'gsat')" />影像地圖</td>
# 				<td><input type="radio" name="map_mode" onclick="checkmapmode(ghyb,'ghyb')" onkeypress="checkmapmode(ghyb,'ghyb')"  />混合地圖</td>
#  			</tr>
# 			  </table>
# 			</div>
#
# 		  </div>
# 		</div></td>
# 	  </tr>
# 	</table>
# </div>
# <div id="tools_frame" class="jqmWindow" style="display:none">
# 	<table  width='100%'  border="0" cellpadding="0" cellspacing="0" class="table_bg">
# 	  <tr>
# 		<td><div id="TabbedPanels1" class="TabbedPanels">
# 		  <ul class="TabbedPanelsTabGroup">
# 			<li class="TabbedPanelsTab" tabindex="0" style="background-image: url(/INC/images/green2_bg.gif);">框選範圍</li>
# 			<li ><img width="30" height="25" src="/INC/images/x.png"  alt="關閉" onclick="$('#tools_frame').jqmHide();" onkeypress="$('#dialog').jqmHide();"/></li>
# 		  </ul>
# 		  <div class="TabbedPanelsContentGroup">
# 			<div class="TabbedPanelsContent">
# 			  <table border="0" cellspacing="0" cellpadding="0">
# 				<tr>
# 				<td align="center"><input type="radio" name="map_mode" onclick="checkMapDrawMode(100);$('#tools_frame').jqmHide();" onkeypress="checkMapDrawMode(100);$('#tools_frame').jqmHide();"  />100公尺</td>
# 				<td align="center"><input type="radio" name="map_mode" onclick="checkMapDrawMode(200);$('#tools_frame').jqmHide();" onkeypress="checkMapDrawMode(200);$('#tools_frame').jqmHide();" />200公尺</td>
# 				<td><input type="radio" name="map_mode" onclick="checkMapDrawMode(300);$('#tools_frame').jqmHide();"  onkeypress="checkMapDrawMode(300);$('#tools_frame').jqmHide();" />300公尺</td>
#  			</tr>
# 			  </table>
# 			</div>
# 		  </div>
# 		</div></td>
# 	  </tr>
# 	</table>
# </div>
# <div id="choose" class="jqmWindow" style="display:none">
# 	<table  width='100%'  border="0" cellpadding="0" cellspacing="0" class="table_bg">
# 	  <tr>
# 		<td><div id="TabbedPanels1" class="TabbedPanels">
# 		  <ul class="TabbedPanelsTabGroup">
# 			<li class="TabbedPanelsTab" tabindex="0" style="background-image: url(/INC/images/green2_bg.gif);">圈選範圍</li>
# 			<li ><img width="30" height="25" src="/INC/images/x.png"  alt="關閉" onclick="$('#choose').jqmHide();"  onkeypress="$('#dialog').jqmHide();"/></li>
# 		  </ul>
# 		  <div class="TabbedPanelsContentGroup">
# 			<div class="TabbedPanelsContent">
# 			  <table border="0" cellspacing="0" cellpadding="0">
# 				<tr>
# 				<!--
# 				<td align="center"><input type="radio" name="map_mode" onclick="checkMapDrawModeCircle(250);$('#choose').jqmHide();$(this).attr('checked', false);"  onkeypress="checkMapDrawModeCircle(250);$('#choose').jqmHide();$(this).attr('checked', false);"  />500公尺</td>
# 				-->
# 				<td align="center"><input type="radio" name="map_mode" onclick="checkMapDrawModeCircle(1250);$('#choose').jqmHide();$(this).attr('checked', false);" onkeypress="checkMapDrawModeCircle(1250);$('#choose').jqmHide();$(this).attr('checked', false);" />2.5公里</td>
# 				<td><input type="radio" name="map_mode" onclick="checkMapDrawModeCircle(2500);$('#choose').jqmHide();$(this).attr('checked', false);"   onkeypress="checkMapDrawModeCircle(2500);$('#choose').jqmHide();$(this).attr('checked', false);" />5公里</td>
#  			</tr>
# 			  </table>
# 			</div>
# 		  </div>
# 		</div></td>
# 	  </tr>
# 	</table>
# </div>
# <script language="javascript">
# </script>
#
#  <!--定位面板  -->
#
#
#
# <script type="text/javascript" src="/INC/js/jqModal.js"></script>
# <script type="text/javascript" src="/INC/js/jqDnR.js"></script>
# <script>
# function run_detail(source, top, left,note){
#   var pos = $(".content").position();
# //	$("#footer").animate({
# //	    opacity: 1
# //	  }, 100).animate({
# //	    opacity: 0
# //	  }, 100, function(){
# 				$("#detail").css("display", "block");
# 				$("#detail").css("position", "absolute");
# 				$("#detail").css("top", pos.top-100 );
# 				$("#detail").css("width", "700px" );
# 				showProcessMsg("", "msg_panel", "hide");
# 				if(note!=""){
# 					$("#notelist").show();
# 					$("#list_note").text(note);
# 				}
# //	  });
# }
#
#
# </script>
# <style type="text/css">
# .jqmWindow2 { display: none;position: absolute;top: 30%;left: 25%;}
# .jqmOverlay { background-color: #000; }
# * iframe.jqm {position:absolute;top:0;left:0;z-index:-1;
# 	width: expression(this.parentNode.offsetWidth+'px');
# 	height: expression(this.parentNode.offsetHeight+'px');
# }
#
# .popup_bg {
# 	width: 700px;
# 	background: #F5F1C8;
# 	margin-top: 0;
# 	margin-right: auto;
# 	margin-bottom: 0;
# 	margin-left: auto;
# 	border: 6px solid #CECECE;
# }
#
# .popup_content {
# 	padding: 10px 0;
# }
# .popup_text {
# 	font-family: "Times New Roman", Times, serif;
# 	font-size: 20px;
# 	color: #9F7609;
# 	line-height: 25px;
# 	padding-bottom: 10px;
# 	font-weight: normal;
# 	padding-left: 41px;
# }
# .popup_box {
# 	border: 1px solid #cfcfcf;
# 	width: 800px;
# 	background-color: #f0f0f0;
# 	padding-top: 2px;
# 	padding-left: 2px;
# }
# </style>
#
#
# <div id="detail" class="jqmWindow2" style="display:none;">
# <div align="right" ><table border="1" cellspacing="0" cellpadding="0"><img src="/INC/images/x.png" onclick="$('#detail').jqmHide();" alt="關閉" onkeypress="$('#detail').jqmHide();"></table>
# <div  align="left" class="popup_bg">
#   <div class="popup_content"><!-- end .content -->
#  <div id = 'title_text'></div>
# 	<div id = 'notelist' >
# 	<legend><span class="titleCFont">&nbsp;&nbsp;備&nbsp;&nbsp;註&nbsp;&nbsp;資&nbsp;&nbsp;料</span></legend>
#     <table  width="99%"  border="0" cellspacing="0" cellpadding="0">
#       <tr>
#         <td align="center"><table  width="98%" border="0" cellspacing="0" cellpadding="0">
#           <tr>
#             <td class="popup_box"><table  width="98%" border="0" cellspacing="0" cellpadding="0" id='list_data'>
# 						<div id ='list_note' style="height:50px;overflow:auto;" align="left" ></div>
# 						</table>&nbsp;</td>
#           </tr>
#         </table></td>
#       </tr>
#     </table>
#    <BR>
#    </div>
# 	<div id = 'showdata'>
#    </div>
#
#  </div>
#   <!-- end .container --> </div>
# </div>
#  <!--明細面板  -->
#
# <script>
# $(function() {
# 	 $( "#sysinfodialog" ).dialog({
# 		autoOpen: false,
# 		height: 240,
# 		width: 350,
# 		modal: true,
# 		buttons: {
# 			"參考": function() {
# 				Newopenurl("/INC/download/scratch.pdf");
# 				$( this ).dialog( "close" );
# 			},
# 			"不用": function() {
# 			$( this ).dialog( "close" );
# 			}
# 		}
# 		});
#
# });
#
# </script>
#
#
# </head>
# <div id="sysinfodialog" title="系統資訊" style="display:none">
#     <table width="100%" border="0" cellspacing="0" cellpadding="0">
#       <tr>
#         <td align="left" >親愛的使用者您好：<p></td>
#       </tr>
#       <tr>
#         <td align="left" >　因近期系統更新程式，導致無法查詢問題，如果您有查詢不到結果的問題，請參考系統提供文件，清除使用「瀏覽器」瀏覽記錄，造成您的不便敬請見諒！！</td>
#       </tr>
#     </table>
#
# </div>
#
# 	<script type="text/javascript">
#
# function chang_menu(str){
#     var f = document.getElementById('MenuForm');
#     f.method="post";
#     f.in_type.value = str;
#     f.action="./changemenu.action";
#     f.submit();
# }
# var ui_const='0';
# 		  catchCodeItem('BUILDTYPE','select','Qry_build');
# 		  getCountry("city");
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-42389321-1', 'moi.gov.tw');
#   ga('send', 'pageview');
#
# </script>
# </body></html>

# %% [markdown]
# ##實際看看有唔有資料

# %%
text1="type=UXJ5ZGF0YQ%3D%3D&Qry_city=QQ%3D%3D&Qry_area_office=QTAx&Qry_paytype=MQ%3D%3D&Qry_build=&Qry_price_s=&Qry_price_e=&Qry_unit_price_s=&Qry_unit_price_e=&Qry_p_yyy_s=MTAz&Qry_p_yyy_e=MTA0&Qry_season_s=Mg%3D%3D&Qry_season_e=Mg%3D%3D&Qry_doorno=&Qry_area_s=&Qry_area_e=&Qry_order=UUEwOCZkZXNj&Qry_unit=Mg%3D%3D&Qry_area_srh=&Qry_buildyear_s=&Qry_buildyear_e=&Qry_urban=&Qry_nurban=&Qry_pattern=&Qry_origin=P&Qry_avg=off&struts.token.name=token&token=B89NKP0UBOUKSK63UONWE6N854PP4G1N"

# %%
text11=map(lambda x: x.replace("=",":"),text1.split("&"))

# %%
text12=dict(map(lambda y:tuple(y.split(":")),(map(lambda x:x.replace("%3D","="),text11))))

# %% [markdown]
# ###其實，我們回過頭來偷塞token給它，先忽略下兩行，之後再回來看會更清楚

# %%
text12['token']=settoken_val

# %%
text12
# Out:
# {'Qry_area_e': '',
#  'Qry_area_office': 'QTAx',
#  'Qry_area_s': '',
#  'Qry_area_srh': '',
#  'Qry_avg': 'off',
#  'Qry_build': '',
#  'Qry_buildyear_e': '',
#  'Qry_buildyear_s': '',
#  'Qry_city': 'QQ==',
#  'Qry_doorno': '',
#  'Qry_nurban': '',
#  'Qry_order': 'UUEwOCZkZXNj',
#  'Qry_origin': 'P',
#  'Qry_p_yyy_e': 'MTA0',
#  'Qry_p_yyy_s': 'MTAz',
#  'Qry_pattern': '',
#  'Qry_paytype': 'MQ==',
#  'Qry_price_e': '',
#  'Qry_price_s': '',
#  'Qry_season_e': 'Mg==',
#  'Qry_season_s': 'Mg==',
#  'Qry_unit': 'Mg==',
#  'Qry_unit_price_e': '',
#  'Qry_unit_price_s': '',
#  'Qry_urban': '',
#  'struts.token.name': 'token',
#  'token': 'B89NKP0UBOUKSK63UONWE6N854PP4G1N',
#  'type': 'UXJ5ZGF0YQ=='}

# %%
#finaldata=s.post("http://lvr.land.moi.gov.tw/N11/QryClass_land.action",data=text12)

# %%
#finaldata

# %% [markdown]
# ##發現有名為token的東西，用setToken的方式去得到“暗黑”變數
# （沒跑出來，本來想餵他吃"餅乾"
# coookies 是用來存一些（可能是client端）參數的
# *_ga是給google看的*）

# %%
settoken=s.post("http://lvr.land.moi.gov.tw/N11/pro/setToken.jsp")

# %%
settoken
# Out:
# <Response [200]>

# %%
settoken.encoding
# Out:
# 'UTF-8'

# %%
settoken.text
# Out:
# u'\r\n\r\n\t<input type="hidden" name="struts.token.name" value="token" />\n<input type="hidden" name="token" value="I9ZDRDOSFS4WDB87A2S6TILC5OEDEDMB" />\r\n'

# %% [markdown]
# ###交漂亮湯處理

# %%
from bs4 import BeautifulSoup

# %%
sett=BeautifulSoup(settoken.text)

# %%
tmp=sett.findAll('input',attrs={"name":"token"})#tmp像是list,底下有dict

# %%
settoken_val=tmp[0].get('value')
settoken_val
# Out:
# 'I9ZDRDOSFS4WDB87A2S6TILC5OEDEDMB'

# %% [markdown]
# ##交卷！！

# %%
finaldata=s.post("http://lvr.land.moi.gov.tw/N11/QryClass_land.action",data=text12)

# %%
finaldata
# Out:
# <Response [406]>

# %%
finaldata.text
# Out:
# u'<html><head><title>Apache Tomcat/6.0.36 - Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 406 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The resource identified by this request is only capable of generating responses with characteristics not acceptable according to the request "accept" headers.</u></p><HR size="1" noshade="noshade"><h3>Apache Tomcat/6.0.36</h3></body></html>'

# %%
print finaldata.text
# Out:
# <html><head><title>Apache Tomcat/6.0.36 - Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 406 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The resource identified by this request is only capable of generating responses with characteristics not acceptable according to the request "accept" headers.</u></p><HR size="1" noshade="noshade"><h3>Apache Tomcat/6.0.36</h3></body></html>
